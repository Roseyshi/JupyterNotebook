# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("E:\PROGRAMMING\iris.csv")
df.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN= KNeighborsClassifier(n_neighbors=1)

# %%
#to find out if i have any zeros in the dataframe
(df==0).sum()
# Out:
# Id                   0
# Sepal Length (cm)    0
# Sepal Width (cm)     0
# Petal Length (cm)    0
# Petal Width (cm)     0
# Species              0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.barplot(data=df, x='Sepal Length (cm)', y= 'Sepal Width (cm)')
# Out:
# <AxesSubplot:xlabel='Sepal Length (cm)', ylabel='Sepal Width (cm)'>

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(data= df, x='Species', y= 'Sepal Length (cm)')
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.scatterplot(data= df, x= 'Species', y= 'Sepal Length (cm)')
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(data= df, x= 'Species', y= 'Sepal Width (cm)')
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(data= df, x= 'Species', y= 'Petal Width (cm)')
plt.show()

# %%
plot= plt.figure(figsize= (5,5))
sns.barplot(data= df, x= 'Species', y= 'Petal Length (cm)')
plt.show()
