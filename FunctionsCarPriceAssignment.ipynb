# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("E:\PROGRAMMING\CarPrice_Assignment.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.size
# Out:
# 5330

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#what missing values do we have?
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#we will check how many categories are there in the object columns
print(df.fueltype.value_counts())
print(df.doornumber.value_counts())
print(df.carbody.value_counts())
print(df.drivewheel.value_counts())
print(df.enginetype.value_counts())
print(df.cylindernumber.value_counts())
print(df.fuelsystem.value_counts())
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
# four    115
# two      90
# Name: doornumber, dtype: int64
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
#encoding the categorical data into numerical values
df.replace({'fueltype':{'gas':0, 'diesel':1}},inplace=True)
df.replace({'doornumber':{'four':0, 'two':1}},inplace=True)
df.replace({'carbody':{'sedan':0, 'hatchback':1, 'wagon':2, 'hardtop':3, 'convertible':4}},inplace=True)
df.replace({'drivewheel':{'fwd':0, 'rwd':1,'4wd':2}},inplace=True)
df.replace({'enginetype':{'ohc':0, 'ohcf':1, 'ohcv':2, 'dohc':3, 'l':4, 'rotor':5, 'dohcv':6}},inplace=True)
df.replace({'cylindernumber':{'four':0, 'six':1, 'five':2, 'eight':3, 'two':4, 'three':5, 'twelve':6}},inplace=True)
df.replace({'fuelsystem':{'mpfi':0, '2bbl':1,'idi':2,'1bbl':3, 'spdi':4, '4bbl':5,'mfi':6, 'spfi':7}},inplace=True)

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName  fueltype aspiration  \
# 0       1          3        alfa-romero giulia         0        std
# 1       2          3       alfa-romero stelvio         0        std
# 2       3          1  alfa-romero Quadrifoglio         0        std
# 3       4          2               audi 100 ls         0        std
# 4       5          2                audi 100ls         0        std
#
#    doornumber  carbody  drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0           1        4           1          front       88.6  ...         130
# 1           1        4           1          front       88.6  ...         130
# 2           1        1           1          front       94.5  ...         152
# 3           0        0           0          front       99.8  ...         109
# 4           0        0           2          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
#some info may not be significant so we drop them with drop()function and use the important for y,in this case 'price' is our y
#we remove it from x and take it to y
X=df.drop(['car_ID', 'symboling', 'CarName','aspiration', 'enginelocation', 'price'], axis=1)
Y=df[['price']]

# %%
X
# Out:
#      fueltype  doornumber  carbody  drivewheel  wheelbase  carlength  \
# 0           0           1        4           1       88.6      168.8
# 1           0           1        4           1       88.6      168.8
# 2           0           1        1           1       94.5      171.2
# 3           0           0        0           0       99.8      176.6
# 4           0           0        0           2       99.4      176.6
# ..        ...         ...      ...         ...        ...        ...
# 200         0           0        0           1      109.1      188.8
# 201         0           0        0           1      109.1      188.8
# 202         0           0        0           1      109.1      188.8
# 203         1           0        0           1      109.1      188.8
# 204         0           0        0           1      109.1      188.8
#
#      carwidth  carheight  curbweight  enginetype  cylindernumber  enginesize  \
# ...

# %%
Y
# Out:
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 1 columns]

# %% [markdown]
# To standardize identify the standard deviation

# %%
df.std()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_13800\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# car_ID                59.322565
# symboling              1.245307
# fueltype               0.297446
# doornumber             0.497483
# carbody                0.990944
# drivewheel             0.581148
# wheelbase              6.021776
# carlength             12.337289
# carwidth               2.145204
# carheight              2.443522
# curbweight           520.680204
# enginetype             1.385810
# cylindernumber         0.990703
# enginesize            41.642693
# fuelsystem             1.306058
# boreratio              0.270844
# stroke                 0.313597
# compressionratio       3.972040
# horsepower            39.544167
# peakrpm              476.985643
# ...

# %%
X_train,Y_train,X_train, X_test=train_test_split(X,Y,test_size=0.2, random_state=3)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (205, 20) (164, 1) (41, 1)

# %%
print(df.std())
# Out:
# car_ID                59.322565
# symboling              1.245307
# fueltype               0.297446
# doornumber             0.497483
# carbody                0.990944
# drivewheel             0.581148
# wheelbase              6.021776
# carlength             12.337289
# carwidth               2.145204
# carheight              2.443522
# curbweight           520.680204
# enginetype             1.385810
# cylindernumber         0.990703
# enginesize            41.642693
# fuelsystem             1.306058
# boreratio              0.270844
# stroke                 0.313597
# compressionratio       3.972040
# horsepower            39.544167
# peakrpm              476.985643
# citympg                6.542142
# highwaympg             6.886443
# price               7988.852332
# dtype: float64
# ...

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_standardize=scaler.transform(X_train)
X_train_standardize
# Out:
# array([[ 0.32391824],
#        [ 0.26243639],
#        [-0.01161572],
#        [-0.61165249],
#        [-0.68621559],
#        [ 2.3188083 ],
#        [-0.23399691],
#        [-0.15485537],
#        [-0.46291872],
#        [-0.30555132],
#        [-0.66410828],
#        [-0.98564532],
#        [-0.80826362],
#        [ 0.87189165],
#        [-0.11299538],
#        [ 0.24006746],
#        [-0.23360447],
#        [-0.45585484],
#        [ 3.11938057],
#        [-0.8574491 ],
#        [ 1.63753699],
#        [-0.80904849],
#        [ 0.03416864],
#        [ 4.23390275],
#        [-0.35172812],
#        [ 0.66926315],
#        [-0.07767602],
#        [ 1.05581397],
#        [-0.68477665],
#        [-0.59373118],
#        [ 0.289907  ],
#        [-0.63375979],
#        [ 0.38775473],
#        [-0.63297492],
#        [ 0.45538477],
#        [ 0.02174146],
#        [ 0.52863975],
#        [-0.83259474],
#        [-0.89015222],
#        [-0.05295246],
#        [-0.65089623],
# ...

# %%
X_test_standardize=scaler.transform(X_test)
X_test_standardize
# Out:
# array([[-0.18821255],
#        [-0.66175366],
#        [-0.97609601],
#        [-0.48868877],
#        [-0.69275621],
#        [ 2.42869077],
#        [-0.53447313],
#        [-0.67182622],
#        [-0.82958605],
#        [ 2.76671017],
#        [-0.89538472],
#        [-0.72872964],
#        [-0.82958605],
#        [ 0.1785856 ],
#        [ 2.51371887],
#        [-0.39751249],
#        [-0.79740618],
#        [-0.5152437 ],
#        [-0.49392127],
#        [-0.77281344],
#        [ 1.10552271],
#        [ 0.06085438],
#        [-0.772421  ],
#        [ 0.1198508 ],
#        [-0.31902501],
#        [ 0.4704282 ],
#        [ 1.50842509],
#        [-0.25976696],
#        [ 1.03815429],
#        [ 0.06085438],
#        [-0.90768109],
#        [ 0.61170566],
#        [ 1.17524575],
#        [ 3.65309541],
#        [ 0.34157793],
#        [-0.68791615],
#        [-0.35826875],
#        [ 2.88077864],
#        [ 0.57769442],
#        [-0.48908121],
#        [-0.70963102]])

# %%
X_train_standardize.std()
# Out:
# 1.0

# %%
X_test_standardize.std()
# Out:
# 1.1890024242110777

# %%
type('object')
# Out:
# str
