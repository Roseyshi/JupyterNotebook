# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
quality= pd.read_csv("E:\PROGRAMMING\winequalityN.csv")
quality.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
quality.shape
# Out:
# (6497, 13)

# %%
quality.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [raw]
# Since we have missing datasets, and our dataframe is large enough, we can drop the 18 rows with missing info

# %%
quality.dropna(inplace = True)
quality.shape
# Out:
# (6463, 13)

# %%
quality.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6463.000000       6463.000000  6463.000000     6463.000000
# mean        7.217755          0.339589     0.318758        5.443958
# std         1.297913          0.164639     0.145252        4.756852
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6463.000000          6463.000000           6463.000000  6463.000000
# mean      0.056056            30.516865            115.694492     0.994698
# std       0.035076            17.758815             56.526736     0.003001
# ...

# %%
sns.catplot(x= 'quality', data= quality, kind= 'count')

# %%
sns.countplot(x= 'quality', data= quality)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
quality.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
plot= plt.figure(figsize=(5,5))

sns.barplot(x = 'quality', y = 'volatile acidity', data= quality)

plt.show()

# %% [markdown]
# # From above, the higher the volatile acidity the lower the quality of the wine

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'type',y= 'quality', data= quality)
plt.show()

# %%
quality['type'].value_counts()
quality['type'].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
plot= plt.figure(figsize= (5,5))
sns.barplot(x= 'quality', y= 'type', data= quality)
plt.show()

# %%
quality['fixed acidity'].nunique()
# Out:
# 106

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'fixed acidity', y= 'quality', data= quality)
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'fixed acidity', data= quality)
plt.show()

# %%
quality['citric acid'].nunique()
# Out:
# 89

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x='quality', y= 'citric acid', data= quality)
plt.show()

# %% [markdown]
# # From above, it is clear that the higher the citric acid, the higher the quality of the wine

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'residual sugar', data= quality)
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'chlorides', data= quality)
plt.show()

# %% [markdown]
# # chlorides and quality are inversely related so the higher the chlorides the lower the quality of the wine

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'free sulfur dioxide', data= quality)
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'total sulfur dioxide', data= quality)
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'density', data= quality)
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'pH', data= quality)
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'sulphates', data= quality)
plt.show()

# %%
plot= plt.figure(figsize=(5,5))
sns.barplot(x= 'quality', y= 'alcohol', data= quality)
plt.show()

# %% [markdown]
# # The higher the alcohol content the higher the quality of the wine
